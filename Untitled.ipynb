# %%
import nasdaqdatalink
mydata = nasdaqdatalink.get("FRED/GDP")

# %%
mydata
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  23992.355
#
# [300 rows x 1 columns]

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from lxml import html
import requests
from time import sleep
import json
import argparse
from random import randint

def parse_finance_page(ticker):
	"""
	Grab financial data from NASDAQ page
	
	Args:
		ticker (str): Stock symbol
	
	Returns:
		dict: Scraped data
	"""
	key_stock_dict = {}
	headers = {
				"Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
				"Accept-Encoding":"gzip, deflate",
				"Accept-Language":"en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7",
				"Connection":"keep-alive",
				"Host":"www.nasdaq.com",
				"Referer":"http://www.nasdaq.com",
				"Upgrade-Insecure-Requests":"1",
				"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.119 Safari/537.36"
	}

	# Retrying for failed request
	for retries in range(5):
		try:	
			url = "https://www.nasdaq.com/market-activity/stocks/%s"%(ticker)
			#url = "http://www.nasdaq.com/symbol/%s"%(ticker)
			response = requests.get(url, headers = headers, verify=False)
			
			if response.status_code!=200:
				raise ValueError("Invalid Response Received From Webserver")

			print("Parsing %s"%(url))
			# Adding random delay
			sleep(randint(1,3))	
			parser = html.fromstring(response.text)
			xpath_head = "//div[contains(@id,'pageheader')]//h1//text()"
			xpath_key_stock_table = '//div[contains(@class,"overview-results")]//div[contains(@class,"table-table")]/div'
			xpath_open_price = '//b[contains(text(),"Open Price:")]/following-sibling::span/text()'
			print(xpath_open_price)
			xpath_open_date = '//b[contains(text(),"Open Date:")]/following-sibling::span/text()'
			xpath_close_price = '//b[contains(text(),"Close Price:")]/following-sibling::span/text()'
			xpath_close_date = '//b[contains(text(),"Close Date:")]/following-sibling::span/text()'
			xpath_key = './/div[@class="table-cell"]/b/text()'
			xpath_value = './/div[@class="table-cell"]/text()'

			raw_name = parser.xpath(xpath_head)
			print("Raw Name:" , raw_name)
			key_stock_table =  parser.xpath(xpath_key_stock_table)
			raw_open_price = parser.xpath(xpath_open_price)
			raw_open_date = parser.xpath(xpath_open_date)
			raw_close_price = parser.xpath(xpath_close_price)
			raw_close_date = parser.xpath(xpath_close_date)

			company_name = raw_name[0].replace("Common Stock Quote & Summary Data","").strip() if raw_name else ''
			open_price =raw_open_price[0].strip() if raw_open_price else None
			open_date = raw_open_date[0].strip() if raw_open_date else None
			close_price = raw_close_price[0].strip() if raw_close_price else None
			close_date = raw_close_date[0].strip() if raw_close_date else None

			# Grabbing and cleaning keystock data
			for i in key_stock_table:
				key = i.xpath(xpath_key)
				value = i.xpath(xpath_value)

				key = ''.join(key).strip() 
				value = ' '.join(''.join(value).split()) 
				key_stock_dict[key] = value

			nasdaq_data = {

							"company_name":company_name,
							"ticker":ticker,
							"url":url,
							"open price":open_price,
							"open_date":open_date,
							"close_price":close_price,
							"close_date":close_date,
							"key_stock_data":key_stock_dict
			}
			return nasdaq_data

		except Exception as e:
			print("Failed to process the request, Exception:%s"%(e))

if __name__=="__main__":

	argparser = argparse.ArgumentParser()
	argparser.add_argument('ticker',help = 'Company stock symbol')
	args = argparser.parse_args()
	ticker = args.ticker
	print("Fetching data for %s"%(ticker))
	scraped_data = parse_finance_page(ticker)
	print("Writing scraped data to output file")

	with open('%s-summary.json'%(ticker),'w') as fp:
		json.dump(scraped_data,fp,indent = 4,ensure_ascii=False)
# Out:
# usage: ipykernel_launcher.py [-h] ticker
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
#python3 nasdaq_finance.py stock symbol
#nasdaq_finance.py aapl
parse_finance_page("aapl")
# Out:
# /Users/evejcik/opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Parsing https://www.nasdaq.com/market-activity/stocks/aapl
# //b[contains(text(),"Open Price:")]/following-sibling::span/text()
# Raw Name: []
# {'company_name': '',
#  'ticker': 'aapl',
#  'url': 'https://www.nasdaq.com/market-activity/stocks/aapl',
#  'open price': None,
#  'open_date': None,
#  'close_price': None,
#  'close_date': None,
#  'key_stock_data': {}}

# %%
from yahoo_fin import options

# %%
nflx_dates = options.get_expiration_dates("nflx")
nflx_dates
# Out:
# ['May 20, 2022',
#  'May 27, 2022',
#  'June 3, 2022',
#  'June 10, 2022',
#  'June 17, 2022',
#  'June 24, 2022',
#  'July 1, 2022',
#  'July 15, 2022',
#  'August 19, 2022',
#  'September 16, 2022',
#  'November 18, 2022',
#  'December 16, 2022',
#  'January 20, 2023',
#  'March 17, 2023',
#  'June 16, 2023',
#  'January 19, 2024']

# %%
chain = options.get_options_chain("nflx")
chain["calls"]
chain["puts"]
# Out:
#            Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0    NFLX220520P00100000   2022-05-18 1:41PM EDT   100.0        0.01    0.00
# 1    NFLX220520P00105000   2022-05-18 2:16PM EDT   105.0        0.01    0.00
# 2    NFLX220520P00110000  2022-05-18 11:19AM EDT   110.0        0.01    0.00
# 3    NFLX220520P00115000   2022-05-18 2:46PM EDT   115.0        0.02    0.00
# 4    NFLX220520P00120000   2022-05-19 2:31PM EDT   120.0        0.01    0.00
# ..                   ...                     ...     ...         ...     ...
# 147  NFLX220520P00620000  2022-03-15 12:55PM EDT   620.0      282.19  274.75
# 148  NFLX220520P00640000  2022-02-10 11:32AM EDT   640.0      236.24  295.60
# 149  NFLX220520P00660000  2022-05-10 10:06AM EDT   660.0      479.90  474.20
# 150  NFLX220520P00700000   2022-02-14 1:00AM EDT   700.0      297.56    0.00
# 151  NFLX220520P00720000  2022-05-18 12:45PM EDT   720.0      540.10  535.45
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
# 0      0.01     0.0        -      3          2038            362.50%
# 1      0.01     0.0        -     21          1167            337.50%
# 2      0.01     0.0        -      2           800            312.50%
# 3      0.02     0.0        -      5          1634            303.13%
# 4      0.01     0.0        -      3           526            262.50%
# ..      ...     ...      ...    ...           ...                ...
# 147  279.90     0.0        -      4             0              0.00%
# 148  301.60     0.0        -      3             4              0.00%
# 149  477.85     0.0        -      1             0            812.50%
# 150    0.00     0.0        -      -             -              0.00%
# 151  535.95     0.0        -      2             -              0.00%
#
# [152 rows x 11 columns]

# %%
#Get current/past call and put options

from yahoo_fin import stock_info as si
 
dow_tickers = si.tickers_dow()
 
# replace DOW with DWDP in ticker list
dow_tickers.remove("DOW")
dow_tickers.append("DWDP")
 
# scrape the options data for each Dow ticker
dow_data = {}
for ticker in dow_tickers:
    try:
        dow_data[ticker] = options.get_options_chain(ticker)
    except Exception:
        print(ticker + " failed")
# Out:
# INTC failed

# %%
dow_data["AAPL"]["calls"]
# Out:
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   AAPL220520C00055000   2022-05-20 9:35AM EDT    55.0       83.35  81.95
# 1   AAPL220520C00060000   2022-05-19 9:32AM EDT    60.0       81.00  77.05
# 2   AAPL220520C00065000  2022-05-06 10:40AM EDT    65.0       91.95  71.85
# 3   AAPL220520C00070000  2022-05-16 12:08AM EDT    70.0       70.75  67.05
# 4   AAPL220520C00075000   2022-05-10 3:53PM EDT    75.0       79.45  61.90
# ..                  ...                     ...     ...         ...    ...
# 69  AAPL220520C00260000   2022-05-06 9:30AM EDT   260.0        0.01   0.00
# 70  AAPL220520C00270000   2022-05-03 1:35PM EDT   270.0        0.01   0.00
# 71  AAPL220520C00280000   2022-05-10 2:43PM EDT   280.0        0.01   0.00
# 72  AAPL220520C00290000   2022-05-10 9:30AM EDT   290.0        0.01   0.00
# 73  AAPL220520C00300000  2022-05-20 10:28AM EDT   300.0        0.01   0.00
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   82.10    -1.0   -1.19%      1             16            681.25%
# 1   77.20     0.0        -      2              2            650.00%
# 2   72.00     0.0        -      1              1              0.00%
# 3   67.30     0.0        -      -              1            572.66%
# 4   62.20     0.0        -     24             13            325.00%
# ..    ...     ...      ...    ...            ...                ...
# 69   0.01     0.0        -      2           1142            375.00%
# 70   0.01     0.0        -     10           1437            387.50%
# 71   0.01     0.0        -      1            829            412.50%
# 72   0.01     0.0        -      1            712            425.00%
# 73   0.01     0.0        -     65           3837            450.00%
#
# [74 rows x 11 columns]

# %%
#Get current stock price

#soup = BeautifulSoup(response.text, "html.parser")
#class_ = "My(6px) Pos(r) smartphone_Mt(6px) W(100%)"

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

def stock_price(symbol: str = "AAPL") -> str:
    url = f"https://finance.yahoo.com/quote/{symbol}/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    class_ = "My(6px) Pos(r) smartphone_Mt(6px) W(100%)"
    return soup.find("div", class_=class_).find("span").text


if __name__ == "__main__":
    symbol = "AAPL"
    #for symbol in "AAPL AMZN IBM GOOG MSFT ORCL".split():
    print(f"Current {symbol:<4} stock price is {stock_price(symbol):>8}")
# Out:
# Current AAPL stock price is    -0.47

# %%
#current stock price
#https://iq.opengenus.org/current-stock-price-in-python/

from yahoo_fin import stock_info as si
si.get_live_price("aapl")
# Out:
# 135.5399932861328

# %%
from yahoo_fin.options import *

# %%
get_calls('nflx')
# Out:
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
# 1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
# 2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
# 3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
# 4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
# ..                  ...                     ...     ...         ...    ...
# 90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
# 91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
# 92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
# 93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
# 94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#       Ask  Change % Change Volume Open Interest Implied Volatility
# 0   87.55   -4.07   -4.52%      2            33            280.08%
# 1   77.80    0.00        -     82            95            253.42%
# 2   67.60    0.00        -     47           103            210.89%
# 3   62.65    0.00        -     21            47            196.44%
# 4   57.70    0.00        -      2            32            182.23%
# ..    ...     ...      ...    ...           ...                ...
# 90   0.05    0.00        -      -             1            256.25%
# 91   0.38    0.00        -      -             2            312.50%
# 92   0.05    0.00        -     16            16            262.50%
# 93   0.28    0.00        -      -             8            314.06%
# 94   0.03    0.00        -      -             5            262.50%
#
# [95 rows x 11 columns]

# %%
get_expiration_dates('nflx')
# Out:
# ['May 27, 2022',
#  'June 3, 2022',
#  'June 10, 2022',
#  'June 17, 2022',
#  'June 24, 2022',
#  'July 1, 2022',
#  'July 15, 2022',
#  'August 19, 2022',
#  'September 16, 2022',
#  'November 18, 2022',
#  'December 16, 2022',
#  'January 20, 2023',
#  'March 17, 2023',
#  'June 16, 2023',
#  'January 19, 2024']

# %%
nflx_dates= options.get_expiration_dates("nflx")
 
info = {}
for date in nflx_dates:
    info[date] = options.get_options_chain("nflx")

# %%
info
# Out:
# {'May 27, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'June 3, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'June 10, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'June 17, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'June 24, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'July 1, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'July 15, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.00
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            107.81%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'August 19, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'September 16, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'November 18, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'December 16, 2022': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'January 20, 2023': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.00
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            107.81%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'March 17, 2023': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'June 16, 2023': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]},
#  'January 19, 2024': {'calls':           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
#   0   NFLX220527C00100000  2022-05-20 10:14AM EDT   100.0       85.97  83.10
#   1   NFLX220527C00110000  2022-05-17 12:37PM EDT   110.0       80.13  73.05
#   2   NFLX220527C00120000   2022-05-17 2:41PM EDT   120.0       68.62  63.05
#   3   NFLX220527C00125000   2022-05-18 1:00PM EDT   125.0       56.12  58.05
#   4   NFLX220527C00130000   2022-05-18 3:54PM EDT   130.0       47.15  53.05
#   ..                  ...                     ...     ...         ...    ...
#   90  NFLX220527C00570000   2022-05-04 9:30AM EDT   570.0        0.58   0.00
#   91  NFLX220527C00580000   2022-04-21 9:30AM EDT   580.0        0.31   0.00
#   92  NFLX220527C00590000   2022-04-25 2:45PM EDT   590.0        0.01   0.00
#   93  NFLX220527C00610000   2022-04-20 3:56PM EDT   610.0        0.15   0.00
#   94  NFLX220527C00620000  2022-04-20 10:25AM EDT   620.0        0.05   0.00
#
#         Ask  Change % Change Volume Open Interest Implied Volatility
#   0   87.55   -4.07   -4.52%      2            33            280.08%
#   1   77.80    0.00        -     82            95            253.42%
#   2   67.60    0.00        -     47           103            210.89%
#   3   62.65    0.00        -     21            47            196.44%
#   4   57.70    0.00        -      2            32            182.23%
#   ..    ...     ...      ...    ...           ...                ...
#   90   0.05    0.00        -      -             1            256.25%
#   91   0.38    0.00        -      -             2            312.50%
#   92   0.05    0.00        -     16            16            262.50%
#   93   0.28    0.00        -      -             8            314.06%
#   94   0.03    0.00        -      -             5            262.50%
#
#   [95 rows x 11 columns],
#   'puts':           Contract Name         Last Trade Date  Strike  Last Price     Bid  \
#   0   NFLX220527P00100000   2022-05-20 2:39PM EDT   100.0        0.01    0.00
#   1   NFLX220527P00105000   2022-05-20 3:37PM EDT   105.0        0.01    0.00
#   2   NFLX220527P00110000   2022-05-20 3:55PM EDT   110.0        0.01    0.00
#   3   NFLX220527P00115000   2022-05-20 3:43PM EDT   115.0        0.02    0.01
#   4   NFLX220527P00120000   2022-05-20 2:13PM EDT   120.0        0.01    0.01
#   ..                  ...                     ...     ...         ...     ...
#   83  NFLX220527P00490000   2022-04-20 2:19PM EDT   490.0      267.47  302.40
#   84  NFLX220527P00500000  2022-04-21 12:39PM EDT   500.0      280.98  312.45
#   85  NFLX220527P00510000   2022-04-25 9:33AM EDT   510.0      295.31  322.40
#   86  NFLX220527P00540000   2022-04-19 3:59PM EDT   540.0      191.48  353.60
#   87  NFLX220527P00600000   2022-04-25 9:32AM EDT   600.0      385.41  412.45
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility
#   0     0.01   -0.01  -50.00%    197            276            140.63%
#   1     0.01    0.00        -    351            113            131.25%
#   2     0.02   -0.01  -50.00%    718            257            128.13%
#   3     0.05   -0.02  -50.00%    320             94            130.47%
#   4     0.02   -0.03  -75.00%     97            210            111.72%
#   ..     ...     ...      ...    ...            ...                ...
#   83  307.05    0.00        -      -              0            342.58%
#   84  317.05    0.00        -      -              0            349.41%
#   85  327.05    0.00        -      1              0            353.61%
#   86  359.40    0.00        -      -              0            434.47%
#   87  417.00    0.00        -      1              0            397.27%
#
#   [88 rows x 11 columns]}}

# %%
url = "https://www.nasdaq.com/market-activity/stocks/aapl/option-chain"

# %%
from urllib.request import urlopen
page = urlopen(url)

# %%
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)

# %%
#https://www.codearmo.com/python-tutorial/options-trading-getting-options-data-yahoo-finance

import pandas as pd
import pandas_datareader.data as web
import numpy as np

FB = web.YahooOptions('FB')

#print(FB)

print(FB.expiry_dates)


#showing available expiries
for exp in FB.expiry_dates:
     print(exp.isoformat())

# get call data
calls = FB.get_call_data()
calls

#get put data
puts  = FB.get_put_data()
puts


#get call data based on specific expiry
FB.get_call_data(month =2 , year = 2021)

# getting all call data, can also pass in a datetime to the expiry below
allcalls = FB.get_call_data(expiry= FB.expiry_dates)

#notice index is in multiindex
allcalls.index

#changing to regular index
allcalls.reset_index(inplace=True)

#get all available data for puts and calls at every expiration
alloptions = FB.get_all_data()

alloptions.reset_index(inplace=True)

# perform calculate on the data.
alloptions['mid_price'] = (alloptions.Ask - alloptions.Bid) / 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/options.py:666, in Options.expiry_dates(self)
#     665 try:
# --> 666     expiry_dates = self._expiry_dates
#     667 except AttributeError:
#
# AttributeError: 'Options' object has no attribute '_expiry_dates'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Input In [63], in <cell line: 11>()
#       7 FB = web.YahooOptions('FB')
#       9 #print(FB)
# ---> 11 print(FB.expiry_dates)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/options.py:668, in Options.expiry_dates(self)
#     666     expiry_dates = self._expiry_dates
#     667 except AttributeError:
# --> 668     expiry_dates = self._get_expiry_dates()
#     669 return expiry_dates
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/options.py:681, in Options._get_expiry_dates(self)
#     672 """
#     673 Gets available expiry dates.
#     674
#    (...)
#     677 List of datetime.date objects
#     678 """
#     680 url = self._OPTIONS_BASE_URL.format(sym=self.symbol)
# --> 681 jd = self._parse_url(url)
#     683 expiry_dates = [
#     684     dt.datetime.utcfromtimestamp(ts).date()
#     685     for ts in jd["optionChain"]["result"][0]["expirationDates"]
#     686 ]
#     688 if len(expiry_dates) == 0:
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/yahoo/options.py:707, in Options._parse_url(self, url)
#     694 def _parse_url(self, url):
#     695     """
#     696
#     697     Downloads and parses a URL into a json object.
#    (...)
#     705     A JSON object
#     706     """
# --> 707     jd = json.loads(self._read_url_as_StringIO(url).read())
#     708     if jd is None:  # pragma: no cover
#     709         raise RemoteDataError(
#     710             "Parsed URL {0!r} is not " "a valid json object".format(url)
#     711         )
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py:119, in _BaseReader._read_url_as_StringIO(self, url, params)
#     115 def _read_url_as_StringIO(self, url, params=None):
#     116     """
#     117     Open url (and retry)
#     118     """
# --> 119     response = self._get_response(url, params=params)
#     120     text = self._sanitize_response(response)
#     121     out = StringIO()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas_datareader/base.py:181, in _BaseReader._get_response(self, url, params, headers)
#     178 if last_response_text:
#     179     msg += "\nResponse Text:\n{0}".format(last_response_text)
# --> 181 raise RemoteDataError(msg)
#
# RemoteDataError: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/options/FB
# Response Text:
# b'Forbidden'

# %%
# specific expiration date
options.get_options_chain("aapl", "04/26/2022")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 2>()
#       1 # specific expiration date
# ----> 2 options.get_options_chain("aapl", "04/26/2022")
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/yahoo_fin/options.py:42, in get_options_chain(ticker, date, raw, headers)
#      33 """Extracts call / put option tables for input ticker and expiration date.  If
#      34    no date is input, the default result will be the earliest expiring
#      35    option chain from the current date.
#      36
#      37    @param: ticker
#      38    @param: date"""
#      40 site = build_options_url(ticker, date)
# ---> 42 tables = pd.read_html(requests.get(site, headers=headers).text)
#      44 if len(tables) == 1:
#      45     calls = tables[0].copy()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:299, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     294     msg = (
#     295         f"Starting with Pandas version {version} all arguments of "
#     296         f"{func.__name__}{arguments} will be keyword-only"
#     297     )
#     298     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/io/html.py:1085, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1081 validate_header_arg(header)
#    1083 io = stringify_path(io)
# -> 1085 return _parse(
#    1086     flavor=flavor,
#    1087     io=io,
#    1088     match=match,
#    1089     header=header,
#    1090     index_col=index_col,
#    1091     skiprows=skiprows,
#    1092     parse_dates=parse_dates,
#    1093     thousands=thousands,
#    1094     attrs=attrs,
#    1095     encoding=encoding,
#    1096     decimal=decimal,
#    1097     converters=converters,
#    1098     na_values=na_values,
#    1099     keep_default_na=keep_default_na,
#    1100     displayed_only=displayed_only,
#    1101 )
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/io/html.py:913, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     911 else:
#     912     assert retained is not None  # for mypy
# --> 913     raise retained
#     915 ret = []
#     916 for table in tables:
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/io/html.py:893, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     890 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     892 try:
# --> 893     tables = p.parse_tables()
#     894 except ValueError as caught:
#     895     # if `io` is an io-like object, check if it's seekable
#     896     # and try to rewind it before trying the next parser
#     897     if hasattr(io, "seekable") and io.seekable():
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/io/html.py:213, in _HtmlFrameParser.parse_tables(self)
#     205 def parse_tables(self):
#     206     """
#     207     Parse and return all tables from the DOM.
#     208
#    (...)
#     211     list of parsed (header, body, footer) tuples from tables.
#     212     """
# --> 213     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/io/html.py:543, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     540 tables = doc.find_all(element_name, attrs=attrs)
#     542 if not tables:
# --> 543     raise ValueError("No tables found")
#     545 result = []
#     546 unique_tables = set()
#
# ValueError: No tables found
